# %% [markdown]
# <a href="https://colab.research.google.com/github/AmrRagab0/-SAAT-Semi-Automated-Annotation-Technique-/blob/main/Scraping_for_matches.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # This notebook's scrapes websites like (youtube, https://www.sport-video.org.ua/football1.html ) for matches and automates their downloading process

# %%
import requests
from bs4 import BeautifulSoup
import os
from urllib.parse import urljoin

# Base URL of the website
base_url = 'https://www.sport-video.org.ua'

# Headers to mimic a browser request
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
}

# Function to extract match links from a football page
def get_match_links(page_url):
    response = requests.get(page_url, headers=headers)
    soup = BeautifulSoup(response.content, 'html.parser')

    # Find all match links
    match_links = []
    for link in soup.find_all('a', href=True):
        if 'html' in link['href']:  # Assuming match pages have .html in their URLs
            # Convert relative URL to absolute URL
            absolute_url = urljoin(base_url, link['href'])
            match_links.append(absolute_url)

    return match_links

# Function to extract torrent links from a match page
def get_torrent_link(match_url):
    response = requests.get(match_url, headers=headers)
    soup = BeautifulSoup(response.content, 'html.parser')

    # Find the torrent link
    for link in soup.find_all('a', href=True):
        if 'torrent' in link['href']:
            # Convert relative URL to absolute URL
            absolute_url = urljoin(base_url, link['href'])
            return absolute_url

    return None

# Function to download a torrent file
def download_torrent(torrent_url, download_dir):
    response = requests.get(torrent_url, headers=headers)
    filename = os.path.join(download_dir, torrent_url.split('/')[-1])

    # Save the torrent file
    with open(filename, 'wb') as file:
        file.write(response.content)

    print(f'Downloaded: {filename}')

# Main script
def main():
    # Directory to save the torrent files
    download_dir = 'torrents'
    os.makedirs(download_dir, exist_ok=True)

    # List to store all match links
    all_match_links = []

    # Step 1: Generate football page URLs (football1.html to football20.html)
    football_pages = [f'{base_url}/football{i}.html' for i in range(1, 21)]

    # Step 2: Scrape match links from each football page
    for page_url in football_pages:
        print(f'Processing football page: {page_url}')
        match_links = get_match_links(page_url)
        all_match_links.extend(match_links)

    # Ensure we have 100 matches
    all_match_links = all_match_links[:100]

    # Step 3: Extract torrent links and download the files
    for match_link in all_match_links:
        print(f'Processing match page: {match_link}')
        torrent_link = get_torrent_link(match_link)

        if torrent_link:
            download_torrent(torrent_link, download_dir)
        else:
            print(f'No torrent link found for: {match_link}')

# Run the script
if __name__ == '__main__':
    main()
# Out:
# Processing football page: https://www.sport-video.org.ua/football1.html
# Processing football page: https://www.sport-video.org.ua/football2.html
# Processing football page: https://www.sport-video.org.ua/football3.html
# Processing football page: https://www.sport-video.org.ua/football4.html
# Processing football page: https://www.sport-video.org.ua/football5.html
# Processing football page: https://www.sport-video.org.ua/football6.html
# Processing football page: https://www.sport-video.org.ua/football7.html
# Processing football page: https://www.sport-video.org.ua/football8.html
# Processing football page: https://www.sport-video.org.ua/football9.html
# Processing football page: https://www.sport-video.org.ua/football10.html
# Processing football page: https://www.sport-video.org.ua/football11.html
# Processing football page: https://www.sport-video.org.ua/football12.html
# Processing football page: https://www.sport-video.org.ua/football13.html
# Processing football page: https://www.sport-video.org.ua/football14.html
# Processing football page: https://www.sport-video.org.ua/football15.html
# Processing football page: https://www.sport-video.org.ua/football16.html
# Processing football page: https://www.sport-video.org.ua/football17.html
# Processing football page: https://www.sport-video.org.ua/football18.html
# Processing football page: https://www.sport-video.org.ua/football19.html
# Processing football page: https://www.sport-video.org.ua/football20.html
# Processing match page: https://www.sport-video.org.ua/football.html
# Downloaded: torrents/Real Madrid - Atletico Madrid 08.02.2025.mkv.torrent
# Processing match page: https://www.sport-video.org.ua/index.html
# No torrent link found for: https://www.sport-video.org.ua/index.html
# Processing match page: https://www.sport-video.org.ua/schedule.html
# No torrent link found for: https://www.sport-video.org.ua/schedule.html
# Processing match page: https://www.sport-video.org.ua/americanfootball.html
# Downloaded: torrents/stream.mkv.torrent
# Processing match page: https://www.sport-video.org.ua/basketball.html
# Downloaded: torrents/Indiana Pacers Los Angeles Lakers 08.02.2025 .mkv.torrent
# Processing match page: https://www.sport-video.org.ua/baseball.html
# No torrent link found for: https://www.sport-video.org.ua/baseball.html
# Processing match page: https://www.sport-video.org.ua/football.html
# Downloaded: torrents/Real Madrid - Atletico Madrid 08.02.2025.mkv.torrent
# Processing match page: https://www.sport-video.org.ua/hockey.html
# Downloaded: torrents/Tampa Bay Lightning at Detroit Red Wings 08.02.2025.mkv.torrent
# Processing match page: https://www.sport-video.org.ua/rugby.html
# Downloaded: torrents/England - France 08.02.2025.mkv.torrent
# Processing match page: https://www.sport-video.org.ua/other.html
# Downloaded: torrents/UFC 312 - Du Plessis vs Strickland 2 08.02.2025.mkv.torrent
# Processing match page: https://www.sport-video.org.ua/filesharing.html
# No torrent link found for: https://www.sport-video.org.ua/filesharing.html
# Processing match page: https://www.sport-video.org.ua/football.html
# Downloaded: torrents/Real Madrid - Atletico Madrid 08.02.2025.mkv.torrent
# Processing match page: https://www.sport-video.org.ua/football.html
# Downloaded: torrents/Real Madrid - Atletico Madrid 08.02.2025.mkv.torrent
# Processing match page: https://www.sport-video.org.ua/football1.html
# No torrent link found for: https://www.sport-video.org.ua/football1.html
# Processing match page: https://www.sport-video.org.ua/football2.html
# No torrent link found for: https://www.sport-video.org.ua/football2.html
# Processing match page: https://www.sport-video.org.ua/football3.html
# No torrent link found for: https://www.sport-video.org.ua/football3.html
# Processing match page: https://www.sport-video.org.ua/football4.html
# No torrent link found for: https://www.sport-video.org.ua/football4.html
# Processing match page: https://www.sport-video.org.ua/football5.html
# No torrent link found for: https://www.sport-video.org.ua/football5.html
# Processing match page: https://www.sport-video.org.ua/football6.html
# No torrent link found for: https://www.sport-video.org.ua/football6.html
# Processing match page: https://www.sport-video.org.ua/football7.html
# No torrent link found for: https://www.sport-video.org.ua/football7.html
# Processing match page: https://www.sport-video.org.ua/football8.html
# No torrent link found for: https://www.sport-video.org.ua/football8.html
# Processing match page: https://www.sport-video.org.ua/football9.html
# No torrent link found for: https://www.sport-video.org.ua/football9.html
# Processing match page: https://www.sport-video.org.ua/football10.html
# No torrent link found for: https://www.sport-video.org.ua/football10.html
# Processing match page: https://www.sport-video.org.ua/football11.html
# No torrent link found for: https://www.sport-video.org.ua/football11.html
# Processing match page: https://www.sport-video.org.ua/football12.html
# No torrent link found for: https://www.sport-video.org.ua/football12.html
# Processing match page: https://www.sport-video.org.ua/football13.html
# No torrent link found for: https://www.sport-video.org.ua/football13.html
# Processing match page: https://www.sport-video.org.ua/football14.html
# No torrent link found for: https://www.sport-video.org.ua/football14.html
# Processing match page: https://www.sport-video.org.ua/football15.html
# No torrent link found for: https://www.sport-video.org.ua/football15.html
# Processing match page: https://www.sport-video.org.ua/football16.html
# No torrent link found for: https://www.sport-video.org.ua/football16.html
# Processing match page: https://www.sport-video.org.ua/football17.html
# No torrent link found for: https://www.sport-video.org.ua/football17.html
# Processing match page: https://www.sport-video.org.ua/football18.html
# No torrent link found for: https://www.sport-video.org.ua/football18.html
# Processing match page: https://www.sport-video.org.ua/football19.html
# No torrent link found for: https://www.sport-video.org.ua/football19.html
# Processing match page: https://www.sport-video.org.ua/football20.html
# No torrent link found for: https://www.sport-video.org.ua/football20.html
# Processing match page: https://www.sport-video.org.ua/football21.html
# No torrent link found for: https://www.sport-video.org.ua/football21.html
# Processing match page: https://www.sport-video.org.ua/football22.html
# No torrent link found for: https://www.sport-video.org.ua/football22.html
# Processing match page: https://www.sport-video.org.ua/football23.html
# No torrent link found for: https://www.sport-video.org.ua/football23.html
# Processing match page: https://www.sport-video.org.ua/football24.html
# No torrent link found for: https://www.sport-video.org.ua/football24.html
# Processing match page: https://www.sport-video.org.ua/football25.html
# No torrent link found for: https://www.sport-video.org.ua/football25.html
# Processing match page: https://www.sport-video.org.ua/football26.html
# No torrent link found for: https://www.sport-video.org.ua/football26.html
# Processing match page: https://www.sport-video.org.ua/football2.html
# No torrent link found for: https://www.sport-video.org.ua/football2.html
# Processing match page: https://www.sport-video.org.ua/RBLWB120125.html
# Downloaded: torrents/RB Leipzig - Werder Bremen 12.01.2025.mkv.torrent
# Processing match page: https://www.sport-video.org.ua/TTH120125.html
# Downloaded: torrents/Tamworth - Tottenham Hotspur 12.01.2025.mkv.torrent
# Processing match page: https://www.sport-video.org.ua/SV110125.html
# Downloaded: torrents/Sevilla - Valencia 11.01.2025.mkv.torrent
# Processing match page: https://www.sport-video.org.ua/ROM110125.html
# Downloaded: torrents/Rennes - Olympique Marseille 11.01.2025.mkv.torrent
# Processing match page: https://www.sport-video.org.ua/MC110125.html
# Downloaded: torrents/Milan - Cagliari 11.01.2025.mkv.torrent
# Processing match page: https://www.sport-video.org.ua/MCSC110125.html
# Downloaded: torrents/Manchester City - Salford City 11.01.2025.mkv.torrent
# Processing match page: https://www.sport-video.org.ua/BMBM110125.html
# Downloaded: torrents/Borussia M'gladbach - Bayern Munchen 11.01.2025.mkv.torrent
# Processing match page: https://www.sport-video.org.ua/RVRB110125.html
# Downloaded: torrents/Real Valladolid - Real Betis 11.01.2025.mkv.torrent
# Processing match page: https://www.sport-video.org.ua/UA110125.html
# Downloaded: torrents/Udinese - Atalanta 11.01.2025.mkv.torrent
# Processing match page: https://www.sport-video.org.ua/RCC110125.html
# Downloaded: torrents/Ross County - Celtic 11.01.2025.mkv.torrent
# Processing match page: https://www.sport-video.org.ua/LAC110125.html
# Downloaded: torrents/Liverpool - Accrington Stanley 11.01.2025.mkv.torrent
# Processing match page: https://www.sport-video.org.ua/AL100125.html
# Downloaded: torrents/Auxerre - Lille 10.01.2025.mkv.torrent
# Processing match page: https://www.sport-video.org.ua/AVWHU100125.html
# Downloaded: torrents/Aston Villa - West Ham United 10.01.2025.mkv.torrent
# Processing match page: https://www.sport-video.org.ua/BDBL100125.html
# Downloaded: torrents/Borussia Dortmund - Bayer Leverkusen 10.01.2025.mkv.torrent
# Processing match page: https://www.sport-video.org.ua/DR090125.html
# Downloaded: torrents/Dundee - Rangers 09.01.2025.mkv.torrent
# Processing match page: https://www.sport-video.org.ua/football.html
# Downloaded: torrents/Real Madrid - Atletico Madrid 08.02.2025.mkv.torrent
# Processing match page: https://www.sport-video.org.ua/football.html
# Downloaded: torrents/Real Madrid - Atletico Madrid 08.02.2025.mkv.torrent
# Processing match page: https://www.sport-video.org.ua/football1.html
# No torrent link found for: https://www.sport-video.org.ua/football1.html
# Processing match page: https://www.sport-video.org.ua/football2.html
# No torrent link found for: https://www.sport-video.org.ua/football2.html
# Processing match page: https://www.sport-video.org.ua/football3.html
# No torrent link found for: https://www.sport-video.org.ua/football3.html
# Processing match page: https://www.sport-video.org.ua/football4.html
# No torrent link found for: https://www.sport-video.org.ua/football4.html
# Processing match page: https://www.sport-video.org.ua/football5.html
# No torrent link found for: https://www.sport-video.org.ua/football5.html
# Processing match page: https://www.sport-video.org.ua/football6.html
# No torrent link found for: https://www.sport-video.org.ua/football6.html
# Processing match page: https://www.sport-video.org.ua/football7.html
# No torrent link found for: https://www.sport-video.org.ua/football7.html
# Processing match page: https://www.sport-video.org.ua/football8.html
# No torrent link found for: https://www.sport-video.org.ua/football8.html
# Processing match page: https://www.sport-video.org.ua/football9.html
# No torrent link found for: https://www.sport-video.org.ua/football9.html
# Processing match page: https://www.sport-video.org.ua/football10.html
# No torrent link found for: https://www.sport-video.org.ua/football10.html
# Processing match page: https://www.sport-video.org.ua/football11.html
# No torrent link found for: https://www.sport-video.org.ua/football11.html
# Processing match page: https://www.sport-video.org.ua/football12.html
# No torrent link found for: https://www.sport-video.org.ua/football12.html
# Processing match page: https://www.sport-video.org.ua/football13.html
# No torrent link found for: https://www.sport-video.org.ua/football13.html
# Processing match page: https://www.sport-video.org.ua/football14.html
# No torrent link found for: https://www.sport-video.org.ua/football14.html
# Processing match page: https://www.sport-video.org.ua/football15.html
# No torrent link found for: https://www.sport-video.org.ua/football15.html
# Processing match page: https://www.sport-video.org.ua/football16.html
# No torrent link found for: https://www.sport-video.org.ua/football16.html
# Processing match page: https://www.sport-video.org.ua/football17.html
# No torrent link found for: https://www.sport-video.org.ua/football17.html
# Processing match page: https://www.sport-video.org.ua/football18.html
# No torrent link found for: https://www.sport-video.org.ua/football18.html
# Processing match page: https://www.sport-video.org.ua/football19.html
# No torrent link found for: https://www.sport-video.org.ua/football19.html
# Processing match page: https://www.sport-video.org.ua/football20.html
# No torrent link found for: https://www.sport-video.org.ua/football20.html
# Processing match page: https://www.sport-video.org.ua/football21.html
# No torrent link found for: https://www.sport-video.org.ua/football21.html
# Processing match page: https://www.sport-video.org.ua/football22.html
# No torrent link found for: https://www.sport-video.org.ua/football22.html
# Processing match page: https://www.sport-video.org.ua/football23.html
# No torrent link found for: https://www.sport-video.org.ua/football23.html
# Processing match page: https://www.sport-video.org.ua/football24.html
# No torrent link found for: https://www.sport-video.org.ua/football24.html
# Processing match page: https://www.sport-video.org.ua/football25.html
# No torrent link found for: https://www.sport-video.org.ua/football25.html
# Processing match page: https://www.sport-video.org.ua/football26.html
# No torrent link found for: https://www.sport-video.org.ua/football26.html
# Processing match page: https://www.sport-video.org.ua/football2.html
# No torrent link found for: https://www.sport-video.org.ua/football2.html
# Processing match page: https://www.sport-video.org.ua/football.html
# Downloaded: torrents/Real Madrid - Atletico Madrid 08.02.2025.mkv.torrent
# Processing match page: https://www.sport-video.org.ua/index.html
# No torrent link found for: https://www.sport-video.org.ua/index.html
# Processing match page: https://www.sport-video.org.ua/schedule.html
# No torrent link found for: https://www.sport-video.org.ua/schedule.html
# Processing match page: https://www.sport-video.org.ua/americanfootball.html
# Downloaded: torrents/stream.mkv.torrent
# Processing match page: https://www.sport-video.org.ua/basketball.html
# Downloaded: torrents/Indiana Pacers Los Angeles Lakers 08.02.2025 .mkv.torrent
# Processing match page: https://www.sport-video.org.ua/baseball.html
# No torrent link found for: https://www.sport-video.org.ua/baseball.html
# Processing match page: https://www.sport-video.org.ua/football.html
# Downloaded: torrents/Real Madrid - Atletico Madrid 08.02.2025.mkv.torrent
# Processing match page: https://www.sport-video.org.ua/hockey.html
# Downloaded: torrents/Tampa Bay Lightning at Detroit Red Wings 08.02.2025.mkv.torrent
# Processing match page: https://www.sport-video.org.ua/rugby.html
# Downloaded: torrents/England - France 08.02.2025.mkv.torrent
# Processing match page: https://www.sport-video.org.ua/other.html
# Downloaded: torrents/UFC 312 - Du Plessis vs Strickland 2 08.02.2025.mkv.torrent
# Processing match page: https://www.sport-video.org.ua/filesharing.html
# No torrent link found for: https://www.sport-video.org.ua/filesharing.html
# Processing match page: https://www.sport-video.org.ua/football1.html
# No torrent link found for: https://www.sport-video.org.ua/football1.html
# Processing match page: https://www.sport-video.org.ua/football.html
# Downloaded: torrents/Real Madrid - Atletico Madrid 08.02.2025.mkv.torrent
# Processing match page: https://www.sport-video.org.ua/football1.html
# No torrent link found for: https://www.sport-video.org.ua/football1.html
# Processing match page: https://www.sport-video.org.ua/football2.html
# No torrent link found for: https://www.sport-video.org.ua/football2.html
# Processing match page: https://www.sport-video.org.ua/football3.html
# No torrent link found for: https://www.sport-video.org.ua/football3.html

# %%
# !rm -rf "/content/torrents"

# %%
# !rmdir --help
# Out:
# Usage: rmdir [OPTION]... DIRECTORY...
# Remove the DIRECTORY(ies), if they are empty.
#
#       --ignore-fail-on-non-empty
#                   ignore each failure that is solely because a directory
#                     is non-empty
#   -p, --parents   remove DIRECTORY and its ancestors; e.g., 'rmdir -p a/b/c' is
#                     similar to 'rmdir a/b/c a/b a'
#   -v, --verbose   output a diagnostic for every directory processed
#       --help     display this help and exit
#       --version  output version information and exit
#
# GNU coreutils online help: <https://www.gnu.org/software/coreutils/>
# Full documentation <https://www.gnu.org/software/coreutils/rmdir>
# or available locally via: info '(coreutils) rmdir invocation'
